# %%
# !kill -9 -1

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install tensorflow
# !pip install ipdb
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (1.13.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.0.9)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.13.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.16.3)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.7.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.12.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.7.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.7.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.0.7)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.33.1)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.13.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow) (0.15.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow) (3.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow) (41.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow) (2.8.0)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow) (2.0.0)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python3.6/dist-packages (from mock>=2.0.0->tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow) (5.1.3)
# Collecting ipdb
#   Downloading https://files.pythonhosted.org/packages/6d/43/c3c2e866a8803e196d6209595020a4a6db1a3c5d07c01455669497ae23d0/ipdb-0.12.tar.gz
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from ipdb) (41.0.1)
# Requirement already satisfied: ipython>=5.1.0 in /usr/local/lib/python3.6/dist-packages (from ipdb) (5.5.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=5.1.0->ipdb) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=5.1.0->ipdb) (4.7.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.1.0->ipdb) (1.0.16)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=5.1.0->ipdb) (2.1.3)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.1.0->ipdb) (0.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython>=5.1.0->ipdb) (4.4.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.1.0->ipdb) (4.3.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=5.1.0->ipdb) (0.6.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.1.0->ipdb) (1.12.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.1.0->ipdb) (0.1.7)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython>=5.1.0->ipdb) (0.2.0)
# Building wheels for collected packages: ipdb
#   Building wheel for ipdb (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/59/24/91/695211bd228d40fb22dff0ce3f05ba41ab724ab771736233f3
# Successfully built ipdb
# Installing collected packages: ipdb
# Successfully installed ipdb-0.12

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os


import ipdb
import time
import cv2
import matplotlib.pyplot as plt

from tensorflow.contrib import rnn 
from keras.preprocessing import sequence
# Out:
# Using TensorFlow backend.

# %%
tf.VERSION
# Out:
# '1.13.1'

# %%
class Video_Caption_Generator():
    def __init__(self, dim_image, n_words, dim_hidden, batch_size, n_lstm_steps, n_video_lstm_step, n_caption_lstm_step, bias_init_vector=None):
        self.dim_image = dim_image
        self.n_words = n_words
        self.dim_hidden = dim_hidden
        self.batch_size = batch_size
        self.n_lstm_steps = n_lstm_steps
        self.n_video_lstm_step=n_video_lstm_step
        self.n_caption_lstm_step=n_caption_lstm_step

        with tf.device("/device:GPU:0"):
            self.Wemb = tf.Variable(tf.random_uniform([n_words, dim_hidden], -0.1, 0.1), name='Wemb')
        #self.bemb = tf.Variable(tf.zeros([dim_hidden]), name='bemb')

        self.lstm1 = tf.nn.rnn_cell.BasicLSTMCell(dim_hidden, state_is_tuple=False)
        self.lstm2 = tf.nn.rnn_cell.BasicLSTMCell(dim_hidden, state_is_tuple=False)

        self.encode_image_W = tf.Variable( tf.random_uniform([dim_image, dim_hidden], -0.1, 0.1), name='encode_image_W')
        self.encode_image_b = tf.Variable( tf.zeros([dim_hidden]), name='encode_image_b')

        self.embed_word_W = tf.Variable(tf.random_uniform([dim_hidden, n_words], -0.1,0.1), name='embed_word_W')
        if bias_init_vector is not None:
            self.embed_word_b = tf.Variable(bias_init_vector.astype(np.float32), name='embed_word_b')
        else:
            self.embed_word_b = tf.Variable(tf.zeros([n_words]), name='embed_word_b')

    def build_model(self):
        video = tf.placeholder(tf.float32, [self.batch_size, self.n_video_lstm_step, self.dim_image])
        video_mask = tf.placeholder(tf.float32, [self.batch_size, self.n_video_lstm_step])

        caption = tf.placeholder(tf.int32, [self.batch_size, self.n_caption_lstm_step+1])
        caption_mask = tf.placeholder(tf.float32, [self.batch_size, self.n_caption_lstm_step+1])

        video_flat = tf.reshape(video, [-1, self.dim_image])
        image_emb = tf.nn.xw_plus_b( video_flat, self.encode_image_W, self.encode_image_b ) # (batch_size*n_lstm_steps, dim_hidden)
        image_emb = tf.reshape(image_emb, [self.batch_size, self.n_lstm_steps, self.dim_hidden])

        state1 = self.lstm1.zero_state(self.batch_size, tf.float32)
        state2 = self.lstm2.zero_state(self.batch_size, tf.float32)
        #state1 = tf.zeros([self.batch_size, self.lstm1.state_size])
        #state2 = tf.zeros([self.batch_size, self.lstm2.state_size])
        padding = tf.zeros([self.batch_size, self.dim_hidden])

        probs = []
        loss = 0.0

        ##############################  Encoding Stage ##################################
        for i in range(0, self.n_video_lstm_step):
            if i > 0:
                tf.get_variable_scope().reuse_variables()

            with tf.variable_scope("LSTM1"):
                output1, state1 = self.lstm1(image_emb[:,i,:], state1)

            with tf.variable_scope("LSTM2"):
                output2, state2 = self.lstm2(tf.concat([padding, output1], 1), state2)

        ############################# Decoding Stage ######################################
        for i in range(0, self.n_caption_lstm_step): ## Phase 2 => only generate captions
            #if i == 0:
            #    current_embed = tf.zeros([self.batch_size, self.dim_hidden])
            #else:
            with tf.device("/device:GPU:0"):
                current_embed = tf.nn.embedding_lookup(self.Wemb, caption[:, i])

            tf.get_variable_scope().reuse_variables()

            with tf.variable_scope("LSTM1"):
                output1, state1 = self.lstm1(padding, state1)

            with tf.variable_scope("LSTM2"):
                output2, state2 = self.lstm2(tf.concat([current_embed, output1], 1), state2)

            labels = tf.expand_dims(caption[:, i+1], 1)
            indices = tf.expand_dims(tf.range(0, self.batch_size, 1), 1)
            concated = tf.concat( [indices, labels], 1)
            onehot_labels = tf.sparse_to_dense(concated, tf.stack([self.batch_size, self.n_words]), 1.0, 0.0)

            logit_words = tf.nn.xw_plus_b(output2, self.embed_word_W, self.embed_word_b)
            cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=logit_words, labels=onehot_labels)
            cross_entropy = cross_entropy * caption_mask[:,i]
            probs.append(logit_words)

            current_loss = tf.reduce_sum(cross_entropy)/self.batch_size
            loss = loss + current_loss

        return loss, video, video_mask, caption, caption_mask, probs


    def build_generator(self):
        video = tf.placeholder(tf.float32, [1, self.n_video_lstm_step, self.dim_image])
        video_mask = tf.placeholder(tf.float32, [1, self.n_video_lstm_step])

        video_flat = tf.reshape(video, [-1, self.dim_image])
        image_emb = tf.nn.xw_plus_b(video_flat, self.encode_image_W, self.encode_image_b)
        image_emb = tf.reshape(image_emb, [1, self.n_video_lstm_step, self.dim_hidden])

        state1 = tf.zeros([1, self.lstm1.state_size])
        state2 = tf.zeros([1, self.lstm2.state_size])
        padding = tf.zeros([1, self.dim_hidden])

        generated_words = []

        probs = []
        embeds = []

        for i in range(0, self.n_video_lstm_step):
            if i > 0:
                tf.get_variable_scope().reuse_variables()

            with tf.variable_scope("LSTM1"):
                output1, state1 = self.lstm1(image_emb[:, i, :], state1)

            with tf.variable_scope("LSTM2"):
                output2, state2 = self.lstm2(tf.concat( [padding, output1], 1), state2)

        for i in range(0, self.n_caption_lstm_step):
            tf.get_variable_scope().reuse_variables()

            if i == 0:
                with tf.device('/device:GPU:0'):
                    current_embed = tf.nn.embedding_lookup(self.Wemb, tf.ones([1], dtype=tf.int64))

            with tf.variable_scope("LSTM1"):
                output1, state1 = self.lstm1(padding, state1)

            with tf.variable_scope("LSTM2"):
                output2, state2 = self.lstm2(tf.concat( [current_embed, output1], 1), state2)

            logit_words = tf.nn.xw_plus_b( output2, self.embed_word_W, self.embed_word_b)
            max_prob_index = tf.argmax(logit_words, 1)[0]
            generated_words.append(max_prob_index)
            probs.append(logit_words)

            with tf.device("/device:GPU:0"):
                current_embed = tf.nn.embedding_lookup(self.Wemb, max_prob_index)
                current_embed = tf.expand_dims(current_embed, 0)

            embeds.append(current_embed)

        return video, video_mask, generated_words, probs, embeds

# %%
#=====================================================================================
# Global Parameters
#=====================================================================================


video_path = '/content/gdrive/My Drive/videoToTexts2vt/youtube_videos'
video_data_path='/content/gdrive/My Drive/s2vt/video_corpus.csv'
video_feat_path = '/content/gdrive/My Drive/videoToTexts2vt/youtube_feats'

vgg16_path = './tensorflow_vgg16/vgg16.tfmodel'


model_path = './models/'

# %%
#=======================================================================================
# Train Parameters
#=======================================================================================
dim_image = 4096
dim_hidden= 1000

n_video_lstm_step = 80
n_caption_lstm_step = 20
n_frame_step = 80

n_epochs = 1010
batch_size = 50
learning_rate = 0.0001

# %%
def get_video_data(video_data_path, video_feat_path, train_ratio=0.9):
    video_data = pd.read_csv(video_data_path, sep=',')
    video_data = video_data[video_data['Language'] == 'English']
    video_data['video_path'] = video_data.apply(lambda row: row['VideoID']+'_'+str(row['Start'])+'_'+str(row['End'])+'.avi.npy', axis=1)
    video_data['video_path'] = video_data['video_path'].map(lambda x: os.path.join(video_feat_path, x))
    video_data = video_data[video_data['video_path'].map(lambda x: os.path.exists( x ))]
    video_data = video_data[video_data['Description'].map(lambda x: isinstance(x, str))]

    unique_filenames = video_data['video_path'].unique()
    train_len = int(len(unique_filenames)*train_ratio)

    train_vids = unique_filenames[:train_len]
    test_vids = unique_filenames[train_len:]

    train_data = video_data[video_data['video_path'].map(lambda x: x in train_vids)]
    test_data = video_data[video_data['video_path'].map(lambda x: x in test_vids)]

    return train_data, test_data

# %%
def preProBuildWordVocab(sentence_iterator, word_count_threshold=5):
    # borrowed this function from NeuralTalk
    print ('preprocessing word counts and creating vocab based on word count threshold %d' % (word_count_threshold))
    word_counts = {}
    nsents = 0
    for sent in sentence_iterator:
        nsents += 1
        for w in sent.lower().split(' '):
           word_counts[w] = word_counts.get(w, 0) + 1
    vocab = [w for w in word_counts if word_counts[w] >= word_count_threshold]
    print ('filtered words from %d to %d' % (len(word_counts), len(vocab)))

    ixtoword = {}
    ixtoword[0] = '<pad>'
    ixtoword[1] = '<bos>'
    ixtoword[2] = '<eos>'
    ixtoword[3] = '<unk>'

    wordtoix = {}
    wordtoix['<pad>'] = 0
    wordtoix['<bos>'] = 1
    wordtoix['<eos>'] = 2
    wordtoix['<unk>'] = 3

    for idx, w in enumerate(vocab):
        wordtoix[w] = idx+4
        ixtoword[idx+4] = w

    word_counts['<pad>'] = nsents
    word_counts['<bos>'] = nsents
    word_counts['<eos>'] = nsents
    word_counts['<unk>'] = nsents

    bias_init_vector = np.array([1.0 * word_counts[ ixtoword[i] ] for i in ixtoword])
    bias_init_vector /= np.sum(bias_init_vector) # normalize to frequencies
    bias_init_vector = np.log(bias_init_vector)
    bias_init_vector -= np.max(bias_init_vector) # shift to nice numeric range

    return wordtoix, ixtoword, bias_init_vector

# %%
def train():
  
    train_data,test_data = get_video_data(video_data_path, video_feat_path, train_ratio=0.9)
    train_captions = train_data['Description'].values
    #test_data = get_video_test_data(video_test_data_path, video_test_feat_path)
    test_captions = test_data['Description'].values
    

    captions_list = list(train_captions) + list(test_captions)
    captions = np.asarray(captions_list, dtype=np.object)

    captions = map(lambda x: x.replace('.', ''), captions)
    captions = map(lambda x: x.replace(',', ''), captions)
    captions = map(lambda x: x.replace('"', ''), captions)
    captions = map(lambda x: x.replace('\n', ''), captions)
    captions = map(lambda x: x.replace('?', ''), captions)
    captions = map(lambda x: x.replace('!', ''), captions)
    captions = map(lambda x: x.replace('\\', ''), captions)
    captions = map(lambda x: x.replace('/', ''), captions)

    wordtoix, ixtoword, bias_init_vector = preProBuildWordVocab(captions, word_count_threshold=0)
    
    np.save("/content/gdrive/My Drive/s2vt/wordtoix", wordtoix)
    np.save('/content/gdrive/My Drive/s2vt/ixtoword', ixtoword)
    np.save("/content/gdrive/My Drive/s2vt/bias_init_vector", bias_init_vector)

    model = Video_Caption_Generator(
            dim_image=dim_image,
            n_words=len(wordtoix),
            dim_hidden=dim_hidden,
            batch_size=batch_size,
            n_lstm_steps=n_frame_step,
            n_video_lstm_step=n_video_lstm_step,
            n_caption_lstm_step=n_caption_lstm_step,
            bias_init_vector=bias_init_vector)

    tf_loss, tf_video, tf_video_mask, tf_caption, tf_caption_mask, tf_probs = model.build_model()
    sess = tf.InteractiveSession()
    
    
    saver = tf.train.Saver(max_to_keep=100)
    with tf.variable_scope(tf.get_variable_scope(), reuse=tf.AUTO_REUSE ) as vscope:
      train_op =  tf.train.AdamOptimizer(learning_rate).minimize(tf_loss)
    tf.global_variables_initializer().run()

    #new_saver = tf.train.Saver()
    #new_saver = tf.train.import_meta_graph('./rgb_models/model-1000.meta')
    #new_saver.restore(sess, tf.train.latest_checkpoint('./models/'))

    loss_fd = open('/content/gdrive/My Drive/s2vt/loss.txt', 'w')
    loss_to_draw = []
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(0, n_epochs):
        loss_to_draw_epoch = []

        index = list(train_data.index)
        np.random.shuffle(index)
        train_data = train_data.loc[index]

        current_train_data = train_data.groupby('video_path').apply(lambda x: x.iloc[np.random.choice(len(x))])
        current_train_data = current_train_data.reset_index(drop=True)
        
        for start, end in zip(
                range(0, len(current_train_data), batch_size),
                range(batch_size, len(current_train_data), batch_size)):

            start_time = time.time()

            current_batch = current_train_data[start:end]
            current_videos = current_batch['video_path'].values

            current_feats = np.zeros((batch_size, n_video_lstm_step, dim_image))
            current_feats_vals = list(map(lambda vid: np.load(vid), current_videos))

            current_video_masks = np.zeros((batch_size, n_video_lstm_step))

            for ind,feat in enumerate(current_feats_vals):
                current_feats[ind][:len(current_feats_vals[ind])] = feat
                current_video_masks[ind][:len(current_feats_vals[ind])] = 1

            current_captions = current_batch['Description'].values
            current_captions = map(lambda x: '<bos> ' + x, current_captions)
            current_captions = map(lambda x: x.replace('.', ''), current_captions)
            current_captions = map(lambda x: x.replace(',', ''), current_captions)
            current_captions = map(lambda x: x.replace('"', ''), current_captions)
            current_captions = map(lambda x: x.replace('\n', ''), current_captions)
            current_captions = map(lambda x: x.replace('?', ''), current_captions)
            current_captions = map(lambda x: x.replace('!', ''), current_captions)
            current_captions = map(lambda x: x.replace('\\', ''), current_captions)
            current_captions = list(map(lambda x: x.replace('/', ''), current_captions))

            for idx, each_cap in enumerate(current_captions):
                word = each_cap.lower().split(' ')
                if len(word) < n_caption_lstm_step:
                    current_captions[idx] = current_captions[idx] + '<eos>'
                else:
                    new_word = ''
                    for i in range(n_caption_lstm_step-1):
                        new_word = new_word + word[i] + ' '
                    current_captions[idx] = new_word + '<eos>'
                #print(current_captions[idx])    

            current_caption_ind = []
            for cap in current_captions:
                current_word_ind = []
                for word in cap.lower().split(' '):
                    if word in wordtoix:
                        current_word_ind.append(wordtoix[word])
                    else:
                        current_word_ind.append(wordtoix['<unk>'])
                current_caption_ind.append(current_word_ind)

            current_caption_matrix = sequence.pad_sequences(current_caption_ind, padding='post', maxlen=n_caption_lstm_step)
            current_caption_matrix = np.hstack( [current_caption_matrix, np.zeros( [len(current_caption_matrix), 1] ) ] ).astype(int)
            current_caption_masks = np.zeros( (current_caption_matrix.shape[0], current_caption_matrix.shape[1]) )
            nonzeros = np.array(list( map(lambda x: (x != 0).sum() + 1, current_caption_matrix ) ))
            #lambda returns list, sum+1 on that list

            for ind, row in enumerate(current_caption_masks):
                row[:nonzeros[ind]] = 1

            probs_val = sess.run(tf_probs, feed_dict={
                tf_video:current_feats,
                tf_caption: current_caption_matrix
                })

            _, loss_val = sess.run(
                    [train_op, tf_loss],
                    feed_dict={
                        tf_video: current_feats,
                        tf_video_mask : current_video_masks,
                        tf_caption: current_caption_matrix,
                        tf_caption_mask: current_caption_masks
                        })
            loss_to_draw_epoch.append(loss_val)

            print( 'idx: ', start, " Epoch: ", epoch, " loss: ", loss_val, ' Elapsed time: ', str((time.time() - start_time)))
            loss_fd.write('epoch ' + str(epoch) + ' loss ' + str(loss_val) + '\n')

       
        if np.mod(epoch, 50) == 0:
            print( "Epoch ", epoch, " is done. Saving the model ...")
            saver.save(sess, os.path.join(model_path, 'model'), global_step=epoch)
             # draw loss curve every epoch
            loss_to_draw.append(np.mean(loss_to_draw_epoch))
            plt_save_dir = "/content/gdrive/My Drive/s2vt/loss_imgs"
            plt_save_img_name = str(epoch) + '.png'
            plt.plot(range(len(loss_to_draw)), loss_to_draw, color='g')
            plt.grid(True)
            plt.xlabel('predicted probability') 
            # naming the y axis 
            plt.ylabel('loss') 
            plt.savefig(os.path.join(plt_save_dir, plt_save_img_name))

            

    sess.close()

# %%
def main():
  train()

# %%
if __name__=="__main__":
    main()
# Out:
# preprocessing word counts and creating vocab based on word count threshold 0
# filtered words from 11286 to 11286
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-3-418898a52437>:15: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7ff90d0112e8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7ff90d0113c8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:From <ipython-input-3-418898a52437>:77: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From <ipython-input-3-418898a52437>:80: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# idx:  500  Epoch:  538  loss:  7.1212997  Elapsed time:  1.1610732078552246
# idx:  550  Epoch:  538  loss:  9.122864  Elapsed time:  1.0046660900115967
# idx:  600  Epoch:  538  loss:  9.341387  Elapsed time:  0.9804935455322266
# idx:  650  Epoch:  538  loss:  6.6965356  Elapsed time:  0.990210771560669
# idx:  700  Epoch:  538  loss:  8.21213  Elapsed time:  0.9968950748443604
# idx:  750  Epoch:  538  loss:  9.638079  Elapsed time:  0.9901120662689209
# idx:  800  Epoch:  538  loss:  7.763791  Elapsed time:  0.9652278423309326
# idx:  850  Epoch:  538  loss:  8.38624  Elapsed time:  0.9484608173370361
# idx:  900  Epoch:  538  loss:  8.750171  Elapsed time:  0.9519240856170654

# %%
tf.InteractiveSession._active_session_count
# Out:
# 0

# %%
tf.global_variables()
# Out:
# [<tf.Variable 'Wemb:0' shape=(2901, 1000) dtype=float32_ref>,
#  <tf.Variable 'encode_image_W:0' shape=(4096, 1000) dtype=float32_ref>,
#  <tf.Variable 'encode_image_b:0' shape=(1000,) dtype=float32_ref>,
#  <tf.Variable 'embed_word_W:0' shape=(1000, 2901) dtype=float32_ref>,
#  <tf.Variable 'embed_word_b:0' shape=(2901,) dtype=float32_ref>,
#  <tf.Variable 'LSTM1/basic_lstm_cell/kernel:0' shape=(2000, 4000) dtype=float32_ref>,
#  <tf.Variable 'LSTM1/basic_lstm_cell/bias:0' shape=(4000,) dtype=float32_ref>,
#  <tf.Variable 'LSTM2/basic_lstm_cell/kernel:0' shape=(3000, 4000) dtype=float32_ref>,
#  <tf.Variable 'LSTM2/basic_lstm_cell/bias:0' shape=(4000,) dtype=float32_ref>,
#  <tf.Variable 'beta1_power:0' shape=() dtype=float32_ref>,
#  <tf.Variable 'beta2_power:0' shape=() dtype=float32_ref>,
#  <tf.Variable 'Wemb/Adam:0' shape=(2901, 1000) dtype=float32_ref>,
#  <tf.Variable 'Wemb/Adam_1:0' shape=(2901, 1000) dtype=float32_ref>,
#  <tf.Variable 'encode_image_W/Adam:0' shape=(4096, 1000) dtype=float32_ref>,
#  <tf.Variable 'encode_image_W/Adam_1:0' shape=(4096, 1000) dtype=float32_ref>,
#  <tf.Variable 'encode_image_b/Adam:0' shape=(1000,) dtype=float32_ref>,
#  <tf.Variable 'encode_image_b/Adam_1:0' shape=(1000,) dtype=float32_ref>,
#  <tf.Variable 'embed_word_W/Adam:0' shape=(1000, 2901) dtype=float32_ref>,
#  <tf.Variable 'embed_word_W/Adam_1:0' shape=(1000, 2901) dtype=float32_ref>,
#  <tf.Variable 'embed_word_b/Adam:0' shape=(2901,) dtype=float32_ref>,
#  <tf.Variable 'embed_word_b/Adam_1:0' shape=(2901,) dtype=float32_ref>,
#  <tf.Variable 'LSTM1/basic_lstm_cell/kernel/Adam:0' shape=(2000, 4000) dtype=float32_ref>,
#  <tf.Variable 'LSTM1/basic_lstm_cell/kernel/Adam_1:0' shape=(2000, 4000) dtype=float32_ref>,
#  <tf.Variable 'LSTM1/basic_lstm_cell/bias/Adam:0' shape=(4000,) dtype=float32_ref>,
#  <tf.Variable 'LSTM1/basic_lstm_cell/bias/Adam_1:0' shape=(4000,) dtype=float32_ref>,
#  <tf.Variable 'LSTM2/basic_lstm_cell/kernel/Adam:0' shape=(3000, 4000) dtype=float32_ref>,
#  <tf.Variable 'LSTM2/basic_lstm_cell/kernel/Adam_1:0' shape=(3000, 4000) dtype=float32_ref>,
#  <tf.Variable 'LSTM2/basic_lstm_cell/bias/Adam:0' shape=(4000,) dtype=float32_ref>,
#  <tf.Variable 'LSTM2/basic_lstm_cell/bias/Adam_1:0' shape=(4000,) dtype=float32_ref>]

# %%
def test(model_path='/content/gdrive/My Drive/s2vt/model-600'):
    #OF = open('/content/gdrive/My Drive/s2vt/out.txt', 'w')
  
    train_data, test_data = get_video_data(video_data_path, video_feat_path, train_ratio=0.9)
    test_videos = test_data['video_path'].unique()

    ixtoword = pd.Series(np.load('/content/gdrive/My Drive/s2vt/ixtoword.npy',allow_pickle=True).tolist())

    bias_init_vector = np.load('/content/gdrive/My Drive/s2vt/bias_init_vector.npy')

    model = Video_Caption_Generator(
            dim_image=dim_image,
            n_words=len(ixtoword),
            dim_hidden=dim_hidden,
            batch_size=batch_size,
            n_lstm_steps=n_frame_step,
            n_video_lstm_step=n_video_lstm_step,
            n_caption_lstm_step=n_caption_lstm_step,
            bias_init_vector=bias_init_vector)

    video_tf, video_mask_tf, caption_tf, probs_tf, last_embed_tf = model.build_generator()
     
    filename='/content/gdrive/My Drive/s2vt/out.txt'
    f = open(filename,'w') 
    
    sess = tf.InteractiveSession()

    saver = tf.train.Saver()
    saver.restore(sess, model_path)

    #test_output_txt_fd = open('S2VT_results.txt', 'w')
    for idx, videos_feat_path in enumerate(test_videos):
        print (idx, videos_feat_path)
        #OF.write(idx, videos_feat_path + "\n")
              
        video_feat = np.load(videos_feat_path)[None,...]
        #video_feat = np.load(videos_feat_path)
        #video_mask = np.ones((videos_feat.shape[0], video_feat.shape[1]))
        if video_feat.shape[1] == n_frame_step:
            video_mask = np.ones((video_feat.shape[0], video_feat.shape[1]))
        else:
            continue
            #shape_templete = np.zeros(shape=(1, n_frame_step, 4096), dtype=float )
            #shape_templete[:video_feat.shape[0], :video_feat.shape[1], :video_feat.shape[2]] = video_feat
            #video_feat = shape_templete
            #video_mask = np.ones((video_feat.shape[0], n_frame_step))

        generated_word_index = sess.run(caption_tf, feed_dict={video_tf:video_feat, video_mask_tf:video_mask})
        generated_words = ixtoword[generated_word_index]
        #print(generated_words)

        punctuation = np.argmax(np.array(generated_words) == '<unk>') 
        #print(punctuation)
        generated_words = generated_words[:punctuation]

        generated_sentence = ' '.join(generated_words)
        generated_sentence = generated_sentence.replace('<bos>', '')
        generated_sentence = generated_sentence.replace('<eos>', '')
        print("Generated this sentence")
        print (generated_sentence,'\n')
        #OF.write(generated_sentence )
        #OF.write("\n")
        #test_output_txt_fd.write(video_feat_path + '\n')
        #test_output_txt_fd.write(generated_sentence + '\n\n')

# %%
test()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-3-418898a52437>:15: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7f232e6a22e8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7f232e6a2400>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/s2vt/model-600
# 0 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/HYbEf-JKZnA_13_26.avi.npy
# Generated this sentence
# a man is taking the
#
# 1 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/hxZ-5wELSJM_0_12.avi.npy
# Generated this sentence
# a man is
#
# 2 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/GnwKcpfr_ng_47_57.avi.npy
# Generated this sentence
# a man is riding a
#
# 3 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/OCcy9TDRGKo_41_51.avi.npy
# Generated this sentence
# a person is cutting the
#
# 4 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/klFyrnrUSck_42_46.avi.npy
# Generated this sentence
# a woman is slicing
#
# 5 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/kBMsuhDvg88_45_64.avi.npy
# Generated this sentence
# a group of men are
#
# 6 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/kWLNZzuo3do_167_181.avi.npy
# Generated this sentence
# a woman is preparing
#
# 7 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/UXs3eq68ZjE_49_54.avi.npy
# Generated this sentence
# a man is adding something to a
#
# 8 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/yPNFVj-pISU_105_115.avi.npy
# Generated this sentence
# a man is riding a
#
# 9 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/Qjbcibrv3L0_26_32.avi.npy
# Generated this sentence
# a man is
#
# 10 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/9Q0JfdP36kI_19_27.avi.npy
# Generated this sentence
# a person is cutting the fat off
#
# 11 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/m1NR0uNNs5Y_192_198.avi.npy
# Generated this sentence
# a person is slicing an
#
# 12 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/c2MwqFYVE7A_40_45.avi.npy
# Generated this sentence
# a boy is doing some
#
# 13 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/jPBxl9gFqNY_110_117.avi.npy
# Generated this sentence
# a man is adding some food to
#
# 14 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/64Xn9edeWRA_0_11.avi.npy
# Generated this sentence
# a man is cleaning the
#
# 15 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/hoinj6vyQ2g_8_16.avi.npy
# Generated this sentence
# a man is playing a
#
# 16 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/-_hbPLsZvvo_269_275.avi.npy
# Generated this sentence
# a woman is preparing
#
# 17 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/g2IYQq7IkXc_23_32.avi.npy
# Generated this sentence
# a man is
#
# 18 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/e4QGnppJ-ys_6_14.avi.npy
# Generated this sentence
# a man is riding a
#
# 19 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/EPgQ9QwbsLE_16_23.avi.npy
# Generated this sentence
# a man is cutting the
#
# 20 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/e996zZ0uV_A_68_72.avi.npy
# Generated this sentence
# a man is riding a
#
# 21 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/hJFBXHtxKIc_163_168.avi.npy
# Generated this sentence
# a man is adding wine to a
#
# 22 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/tn1d5DmdMqY_15_28.avi.npy
# Generated this sentence
# a man is playing a
#
# 23 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/8MVo7fje_oE_180_185.avi.npy
# Generated this sentence
# a man is
#
# 24 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/yOnRm3TP6hM_0_12.avi.npy
# Generated this sentence
# a small dog is playing with the
#
# 25 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/DN7jwyL1Xgg_1_19.avi.npy
# Generated this sentence
# a man is
#
# 26 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/2MCpA01Sn_c_75_82.avi.npy
# Generated this sentence
# a dog is
#
# 27 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/sRKQfxxEP4M_117_125.avi.npy
# Generated this sentence
# a group of people are
#
# 28 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/Z3m9V8qPXhQ_13_24.avi.npy
# Generated this sentence
# a man is playing
#
# 29 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/Ow_o78zjo14_42_57.avi.npy
# Generated this sentence
# a man is
#
# 30 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/5U3xz9Ovmhk_258_265.avi.npy
# Generated this sentence
# a man is mixing some
#
# 31 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/J8cP93yG1Ao_14_24.avi.npy
# Generated this sentence
# a man is
#
# 32 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/BefkDBj5gSw_233_240.avi.npy
# Generated this sentence
# a man is
#
# 33 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/AE9UaQwum8c_0_10.avi.npy
# Generated this sentence
# a man is
#
# 34 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/TZ860P4iTaM_10_24.avi.npy
# Generated this sentence
# a cat is playing the
#
# 35 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/BOv-2HzNPaA_7_12.avi.npy
# Generated this sentence
# a man is
#
# 36 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/Je3V7U5Ctj4_956_961.avi.npy
# Generated this sentence
# a man is putting a bowl of
#
# 37 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/6t0BpjwYKco_105_110.avi.npy
# Generated this sentence
# a woman is cooking some
#
# 38 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/0lh_UWF9ZP4_191_197.avi.npy
# Generated this sentence
# a woman is slicing some
#
# 39 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/xxHx6s_DbUo_182_186.avi.npy
# Generated this sentence
# a man is playing with a
#
# 40 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/_sJ_09Mf1HY_49_72.avi.npy
# Generated this sentence
# the men are
#
# 41 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/zHy7pM0U49w_103_109.avi.npy
# Generated this sentence
# a man is slicing a
#
# 42 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/jxdubZzQrio_33_46.avi.npy
# Generated this sentence
# a woman is
#
# 43 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/xSmfK498DjI_1_20.avi.npy
# Generated this sentence
# a woman is
#
# 44 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/Ms3QdGIzltU_10_20.avi.npy
# Generated this sentence
# a hamster is eating
#
# 45 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/C9LHk0AJI7U_196_205.avi.npy
# Generated this sentence
# a man is putting some food on a
#
# 46 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/hJFBXHtxKIc_225_230.avi.npy
# Generated this sentence
# a man is adding oil to a
#
# 47 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/EwTZ2xpQwpA_14_21.avi.npy
# Generated this sentence
# a man is playing
#
# 48 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/DBvSfds3FH4_84_88.avi.npy
# Generated this sentence
# a man is preparing
#
# 49 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/IhwPQL9dFYc_24_30.avi.npy
# Generated this sentence
# a man is slicing some
#
# 50 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/0lh_UWF9ZP4_165_170.avi.npy
# Generated this sentence
# a woman is putting flour into a
#
# 51 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/xy9LLUUZ6ic_50_60.avi.npy
# Generated this sentence
# a man is watching a
#
# 52 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/JhCvLmf9yr0_46_50.avi.npy
# Generated this sentence
# a woman is peeling a
#
# 53 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/CgWYN5e9K10_30_62.avi.npy
# Generated this sentence
# a man is playing with a
#
# 54 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/JnNe61UZsdM_42_51.avi.npy
# Generated this sentence
# a woman is
#
# 55 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/0lh_UWF9ZP4_157_160.avi.npy
# Generated this sentence
# a woman is mixing
#
# 56 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/229NvV0SRHw_0_5.avi.npy
# Generated this sentence
# a baby is
#
# 57 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/0wutCy2ZGOQ_4_10.avi.npy
# Generated this sentence
# two men are playing with each
#
# 58 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/UgUFP5baQ9Y_0_7.avi.npy
# Generated this sentence
# three women are
#
# 59 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/R8FDJgVW3Vc_0_4.avi.npy
# Generated this sentence
# a man is cutting a
#
# 60 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/clKtfGBVI1I_15_28.avi.npy
# Generated this sentence
# a man is
#
# 61 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/NjblUomxFQo_100_108.avi.npy
# Generated this sentence
# a girl is mixing a
#
# 62 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/vloe_60s_dk_0_9.avi.npy
# Generated this sentence
# a man is
#
# 63 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/UXs3eq68ZjE_246_250.avi.npy
# Generated this sentence
# a man is pouring a food in a
#
# 64 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/HJHPB_Y8GZE_259_263.avi.npy
# Generated this sentence
# a funny
#
# 65 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/5CU2JhYM8tY_14_45.avi.npy
# Generated this sentence
# a woman is
#
# 66 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/a0g7wtBkS98_34_42.avi.npy
# Generated this sentence
# a man is
#
# 67 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/N5wsl86P37Q_1_15.avi.npy
# Generated this sentence
# a man is playing a
#
# 68 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/qeKX-N1nKiM_74_77.avi.npy
# Generated this sentence
# a woman is slicing
#
# 69 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/eZLxohGP4IE_190_201.avi.npy
# Generated this sentence
# a man is cutting a
#
# 70 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/f9_bP219ehQ_63_70.avi.npy
# Generated this sentence
# a man is
#
# 71 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/Uc63MFVwfrs_355_372.avi.npy
# Generated this sentence
# a person is slicing a potato into
#
# 72 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/lKADopH3qFY_0_10.avi.npy
# Generated this sentence
# a cat is playing with a
#
# 73 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/O9yLRzpPp44_167_190.avi.npy
# Generated this sentence
# a woman is putting on a
#
# 74 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/gyOVZz7kXyM_1_10.avi.npy
# Generated this sentence
# a cat is playing with a
#
# 75 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/tHLiYTS9Iz8_1_16.avi.npy
# Generated this sentence
# a man is playing with a
#
# 76 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/6t0BpjwYKco_142_151.avi.npy
# Generated this sentence
# a woman is putting some food into a
#
# 77 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/4yYapi-5QYQ_33_57.avi.npy
# Generated this sentence
# a man is
#
# 78 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/0M-PyX2DbZc_25_31.avi.npy
# Generated this sentence
# a man is
#
# 79 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/t8Nf1MK7lts_0_10.avi.npy
# Generated this sentence
# a man is taking a
#
# 80 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/_OBlgSz8sSM_15_32.avi.npy
# Generated this sentence
# a baby is
#
# 81 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/UbmZAe5u5FI_101_110.avi.npy
# Generated this sentence
# a woman is cleaning a
#
# 82 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/NNYLo1OeZ-Q_48_54.avi.npy
# Generated this sentence
# a man is slicing
#
# 83 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/IAvBB2lv8iw_142_148.avi.npy
# Generated this sentence
# a man is
#
# 84 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/NVGGgncVq-4_12_20.avi.npy
# Generated this sentence
# a man is
#
# 85 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/otLEUwHao_E_140_151.avi.npy
# Generated this sentence
# a man is playing a
#
# 86 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/LwicaralvS0_90_104.avi.npy
# Generated this sentence
# a man is playing a
#
# 87 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/XzCcRzEa83U_39_46.avi.npy
# Generated this sentence
# a man is playing with a
#
# 88 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/wn9rDTZj-m4_8_18.avi.npy
# Generated this sentence
# a woman is
#
# 89 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/Ugb_uH72d0I_8_17.avi.npy
# Generated this sentence
# a man is playing a
#
# 90 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/e-j59PqJjSM_163_173.avi.npy
# Generated this sentence
# a man is slicing a
#
# 91 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/xOQn1z_oWDY_30_39.avi.npy
# Generated this sentence
# a man is
#
# 92 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/UXs3eq68ZjE_209_214.avi.npy
# Generated this sentence
# a man is adding some food to a
#
# 93 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/0hyZ__3YhZc_289_295.avi.npy
# Generated this sentence
# a person is
#
# 94 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/1qV4wfjTYIo_151_164.avi.npy
# Generated this sentence
# a man is adding something to a
#
# 95 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/xfRIRSWy0y0_10_20.avi.npy
# Generated this sentence
# a man is riding a
#
# 96 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/bSrpvMSuhPM_17_31.avi.npy
# Generated this sentence
# a woman is applying
#
# 97 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/bQJQGoJF7_k_145_153.avi.npy
# Generated this sentence
# a man is pouring marinade into a
#
# 98 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/zr9OeyfLPPY_4_9.avi.npy
# Generated this sentence
# a man is
#
# 99 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats
/content/gdrive/My Drive/videoToTexts2vt/youtube_feats/ACOmKiJDkA4_75_81.avi.npy
# Generated this sentence
# a woman is adding some kind of
#
# 133 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/ZDoy9S82ETA_5_15.avi.npy
# Generated this sentence
# a man is riding a
#
# 134 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/BVjvRpmHg0w_231_250.avi.npy
# Generated this sentence
# a man is cooking his
#
# 135 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/MWvCcwTw7Ac_78_86.avi.npy
# Generated this sentence
# a man is walking on a
#
# 136 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/YS1mzzhmWWA_9_16.avi.npy
# Generated this sentence
# a man is cutting a
#
# 137 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/qIk_Dz5XE5E_104_109.avi.npy
# Generated this sentence
# a man is driving a
#
# 138 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/uO7Eysrs8_k_106_114.avi.npy
# Generated this sentence
# a man is riding a
#
# 139 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/lc9bA-hvqHU_1_6.avi.npy
# Generated this sentence
# a man is playing the
#
# 140 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/2YhDTpzxd3c_166_170.avi.npy
# Generated this sentence
# a man is
#
# 141 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/6t0BpjwYKco_230_240.avi.npy
# Generated this sentence
# a woman is slicing some
#
# 142 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/0lh_UWF9ZP4_103_110.avi.npy
# Generated this sentence
# a woman is frying some
#
# 143 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/x68Djm_Q0GA_0_10.avi.npy
# Generated this sentence
# a man is
#
# 144 /content/gdrive/My Drive/videoToTexts2vt/youtube_feats/X6uJyuD_Zso_3_17.avi.npy
# Generated this sentence
# a man is cutting the

# %%
ixtoword = pd.Series(np.load('/content/gdrive/My Drive/s2vt/ixtoword.npy',allow_pickle=True).tolist()) 
for words in ixtoword:
   print(words)
# Out:
# <pad>
# <bos>
# <eos>
# <unk>
# a
# man
# is
# arranging
# sushi
# person
# food
# on
# dish
# making
# hot
# dog
# piece
# look
# like
# an
# octopus
# woman
# arranges
# cuts
# squid
# adding
# eyes
# to
# squash
# cut
# into
# ghost-like
# pieces
# some
# and
# decorating
# it
# preparing
# plate
# of
# places
# sesame
# seeds
# as
# octopus-shaped
# sausage
# placed
# small
# white
# tray
# prepares
# seed
# are
# added
# someone
# with
# made
# the
# lady
# garnishing
# vegetables
# garnish
# bento
# in
# serving
# putting
# vegetable
# showing
# how
# make
# box
# puts
# placing
# black
# thing
# her
# put
# two
# sausages
# platter
# coking
# somebody
# video
# plates
# asian
#
# adds
# full
# fruits
# displayed
# japanese
# boxed
# lunch
# dazzle
# zebras
# grazing
# grassland
# flock
# group
# zebra
# herd
# standing
# field
# graze
# savannah
# stand
# grassy
# plain
# pack
# many
# several
# grazed
# grasses
# eating
# grass
# grassing
# peacefully
# gracing
# jungle
# were
# found
# together
# lots
# all
# forest
# walking
# having
# they
# running
# savanna
# gazing
# fields
# very
# cute
# boy
# does
# flips
# trampoline
# doing
# flipping
# guy
# back
# different
# children
# jump
# trampolines
# kids
# tricks
# people
# jumping
# do
# peoples
# groups
# shown
# up
# down
# boys
# did
# playing
# jumped
# tramplines
# men
# one
# them
# summersaults
# bouncy
# sheet
# net
# somersaulting
# guys
# amazing
# things
# bed
# veri
# nice
# boyes
# can
# be
# bunch
# young
# tranpoline
# male
# players
# ground
# performing
# sick
# trampolin
# practising
# sort
# gymnastic
# steps
# spring
# floor
# adventure
# it
# sparks
# airforce
# adventures
# corsair
# digital
# destruction
# explosive
# single
# skies
# airoplane
# mini-airplane
# flown
# piolot
# above
# radio-controlled
# aeroplane
# adventurously
# flite
# pull-ups
# doorway
# ups
# chin-ups
# bar
# viewing
# hi
# iam
# big
# fan
# pawan
# kalyan﻿
# dont
# compare
# ever
# had
# performed
# extremely
# well
# done
# ability
# hero
# work
# exercising
# bulding
# muscule
# empty
# swishes
# remove
# tin
# tomatoe
# chilly
# rinse
# dregs
# bottle
# 2-
# beam
# int
# wok-like
# beaten
# somoenei
# omelette
# scrambled
# amlate
# means
# loaf
# bake
# easily
# chaped
# ht
# ebread
# bred
# concrete
# sledge
# hammer
# hammers
# cinder
# blocks
# brick
# broken
# body
# chest
# stone
# cement
# block
# sledghammer
# break
# sludgehammer
# learning
# broking
# dare
# seriously
# event
# soldier
# badri
# sprinkled
# purple
# waters
# garden
# hose
# til
# colours
# jogger
# splashed
# dirty
# cooled
# hosed
# sprayed
# polluted
# hosing
# ink
# t-shirt
# asked
# initially
# sprays
# later
# contains
# changing
# squirting
# stains
# pour
# become
# pther
# watered
# dye
# pipe
# coloured
# watering
# switches
# drunk
# drunken
# pushes
# bi-cycle
# ditch
# sideways
# pole
# push
# accidentally
# balance
# whilst
# bicyclehe
# home
# drunkan
# unseccessful
# attempt
# bycle
# mowing
# lawn
# others
# watch
# yard
# onlookers
# smile
# creepily
# watches
# four
# wide-eyed
# flashes
# grin
# skipping
# strange
# declare
# end
# nigh
# unrealistically
# weirdly
# creepy
# pushed
# mower
# scared
# scary
# faces
# sound
# hole
# sun
# walk
# few
# admiring
# heads
# someone's
# resting
# lori
# observes
# walks
# mat
# crawled
# mammal
# th
# loire
# move
# searching
# new
# born
# mouse
# crawling
# blanket
# rat
# lorie's
# 3
# toed
# desk
# smaller
# rectangular
# fom
# visit
# authentic
# cuisine
# wonderful
# performance
# chicken
# meet
# peice
# process
# meals
# 'go
# chi
# so'
# shuffling
# deck
# cards
# card
# trick
# shuffles
# dealing
# shuffled
# models
# living
# circle
# linking
# segment
# america's
# television
# drag
# queens
# moment
# beautiful
# entering
# danced
# circles
# linked
# dips
# corner
# sticking
# swirls
# evenly
# chopsticks
# griddle-like
# personis
# wiyh
# omlette
# filing
# fills
# filling
# spaghetti
# persong
# parking
# store
# crossing
# chuck
# e
# cheese's
# crossed
# children's
# steal
# runinng
# van(the
# shaycarl
# stole
# park
# set
# reach
# destination
# restaurant
# childrens
# ruining
# family
# stealing
# someoen
# omlet
# elderly
# peeler
# terrible
# waste
# pickel
# clara
# 91
# year
# poor
# meal
# depression
# era
# gold-
# idea
# peal
# peel
# today's
# menu
# my
# alcohol
# liquor
# vodka
# alcoholic
# beverage
# sits
# drinkin
# somekind
# due
# depressed
# chugs
# massive
# live
# salmon
# fresh
# wall
# ceiling
# leaps
# house
# scales
# claws
# topmost
# edge
# scrambles
# adjacent
# afraid
# literally
# will
# arrow
# points
# recognize
# silly
# poll
# lustige
# taer
# tears
# tased
# bit
# sandwich
# taste-testing
# breads
# hedgehog
# yellowish
# crumbs
# treats
# bits
# aligned
# row
# someyhing
# view
# jointed
# nose
# freaks
# ﻿it's
# me﻿
# dude
# though
# smmall
# preaparing
# awesome﻿
# cheers
# mate
# splitting
# de-shelled
# caret
# dried
# herbs
# unbaked
# somone
# seasoned
# floured
# thyme
# peeper
# detail
# last
# decoration
# witha
# melts
# melting
# heating
# utensil
# mmelted
# meliting
# details
# boar
# woods
# wild
# trees
# blocked
# charges
# quicker
# the﻿
# sock
# shears
# socks
# knit
# sisser
# wool
# vutting
# shocks
# gingher
# 7-inch
# dressmakers
# curd
# chillies
# dices
# peppers
# scallions
# chili's
# celery
# buttermilk
# north
# grinder
# chile
# olives
# professional
# always
# braces
# knuckles
# origin
# instructions
# onions
# chillie
# chives
# greenchillies
# chilling
# tub
# panel
# pawing
# bathtub
# screen
# erase
# window
# rubs
# fore
# framed
# scatched
# washbasin
# earseable
# clawing
# basin
# whiteboard
# sharpening
# act
# scratch
# tab
# bats
# rhythm
# sharpen
# slick
# stuck
# bubbles
# bobble
# chain
# trics
# soap
# balloons
# magician
# performer
# interlinks
# 8
# bubble
# art
# create
# connected
# connects
# blowig
# rings
# generating
# continuous
# strand
# wands
# chaining
# artistry
# interlocked
# looped
# sticks
# bubles
# such
# tenner
# magic
# guttier
# geter
# learner
# humming
# ringing
# named
# venkat
# gittar
# ingredient
# mandarin
# oranges
# banto
# sprinkles
# roof
# traveling
# loaded
# country
# traveled
# load
# anbe
# sivam
# coming
# tiles
# bricks
# fist
# stack
# martial
# braking
# presenting
# layer
# billing
# cash
# bill
# cutomer
# register
# customers
# purchase
# security
# records
# clerk
# customer
# change
# paying
# merchandise
# shopping
# hardware
# bought
# buying
# status
# shopkeeper
# shoping
# pukau
# di
# johor
# supermarket
# shoppers
# periodically
# assists
# purchases
# bazaar
# leaving
# swapping
# pipes
# surveillance
# departmental
# working
# cashier
# helps
# works
# leave
# order
# complex
# paid
# fillet
# tuna
# ginger
# pickle
# tuber
# nimona
# mashed
# clay
# pots
# kicks
# leg
# jars
# jugs
# smashing
# bowls
# kicke
# containers
# legs
# during
# perpendicular
# ledy
# programme
# healthy
# aboout
# quartering
# sectioning
# bentos
# painted
# applied
# decorates
# applies
# joker
# cosmetics
# painting
# paints
# clown-like
# make-up
# joking
# paining
# session
# cecily
# bret
# batman
# styiling
# themselves
# eyeliner
# give
# paint
# jocker
# tutorial
# prickel
# frances
# dogshow
# lion
# licking
# laying
# rests
# patch
# looked
# calmly
# hungry
# prey
# own
# itself
# tongue
# basking
# scaring
# viewed
# lays
# licks
# lips
# lazily
# plains
# filmed
# adult
# relaxes
# surroundings
# tiger
# lioness
# relaxing
# observing
# diapered
# coffee
# mimic
# imitating
# motions
# kinds
# kidney
# dropped
# types
# dumps
# sooo
# excited
# lol
# question
# plan
# tranig
# cooke
# bench
# rocking
# lap
# save
# cold
# embracing
# forth
# hugs
# comforted
# rocked
# gitanjali
# sand
# tamel
# romancing
# cuple
# removes
# pumpkins
# fryer
# pumpkin
# rack
# attractively
# garnished
# drying
# vcvof
# bioling
# shallow
# golden-brown
# awire
# proper
# technique
# dear
# hopping
# deer
# hops
# chainlink
# adjoining
# cyclone
# wandering
# elite
# finds
# rhrough
# highlight
# boundary
# line
# roaming
# taller
# than
# link
# chain-link
# vidio
# trespassing
# quality﻿
# choping
# knief
# soccer
# feet
# keeping
# rapid
# movements
# football
# fancy
# keep
# एक
# लड़का
# फुटबोल
# पैर
# से
# लोगोके
# बीचमे
# खेला
# रहा
# है
# animated
# version
# rotating
# depicted
# guinness
# bounceing
# involving
# only
# skills
# juggling
# gaming
# fooot
# preforms
# norway
# exhibition
# kick
# rbss
# final
# tobias
# becs
# azun
# feets
# spinning
# audience
# spins
# bounces
# presentation
# besc
# prawns
# skewered
# seafood
# shimp
# boiing
# francine
# foods﻿
# rugby
# touch
# gorup
# nineteen
# counting
# sister
# josie
# wanted
# closer
# arkansas
# hospital
# hours
# decided
# rent
# temporarly
# go
# sandlot
# construction
# firehat
# cheer
# friends
# safety
# diner
# safe
# uniform
# lightening
# explodes
# blasting
# exploded
# structure
# exploding
# missile-like
# burnng
# atmosphere
# firing
# roket
# dangerous
# bomb
# weird
# bolt
# skey
# miccile
# blasted
# blast
# happen
# boy's
# childs
# brother`s
# toddler's
# bitting
# biten
# screaming
# pain
# since
# brother
# index
# right
# figure
# preschool
# age
# approaching
# toddlerdom
# proceeds
# bitten
# brother's
# chutti
# fingerthis
# childhood
# toddlers
# stroller
# ones
# unique
# attachment
# brothers
# kid's
# cries
# elder
# younger
# babies
# said
# charlie
# memories
# spending
# time
# pedals
# pedling
# recumbent
# race
# elongated
# special
# pedaling
# recumbant
# kart
# sean
# costin
# kilometer
# worle
# record-2008
# unusual
# fantastic
# position
# excellent
# futuristic
# tricycle
# transfers
# assorted
# chill
# vagetarian
# vegetaion
# recipee
# retrieves
# grabbing
# popt
# fished
# ouf
# teh
# twig
# digging
# paw
# fishes
# bowel
# fetching
# gate
# barricade
# blocking
# entrance
# followed
# hall
# dark
# mesh
# door
# frame
# fatty
# struggles
# climb
# child's
# follows
# blocker
# deferent
# barrier
# crushed
# sautéed
# i﻿
# should
# spatula
# salad
# vegetaian
# jar
# garlic
# seasing
# presents
# vegatarian
# backwards
# escape
# reverse
# shoulder
# pursuit
# backward
# getaway
# outmaneuvering
# highway
# backed
# patrol
# chased
# authorities
# reversing
# motorway
# fashion
# freeway
# following
# spun
# racer
# backing
# helped
# escaping
# cop
# errant
# attempting
# stop
# suspect
# performs
# surprising
# maneuver
# lanes
# dashing
# fas
# crash
# rong
# cage
# meowing
# snarling
# hissing
# scowling
# meows
# screeching
# growling
# frightened
# strap
# lashes
# betting
# pillar
# whipped
# column
# belt
# whacks
# shipped
# anotehr
# hunter
# cry
# whip
# napoloen
# served
# serve
# pewrson
# seared
# serves
# decorated
# shallo
# cookedturned
# flipped
# knotted
# suspended
# same
# splashing
# outdoor
# warehouse
# shimmied
# climbed
# ladder
# army
# pulled
# hanged
# tag
# tube
# folds
# amulet
# baked
